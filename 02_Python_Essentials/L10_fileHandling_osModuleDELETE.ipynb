# %% [markdown]
# ## What is File Handling?
# File handling in Python allows us to read from and write to files stored on a computer. It is essential for working with **data storage, logging, and configuration files.**
#
# ### File Modes in Python
# Python provides different modes for opening files:
#
# Mode	Description
#
# - r	Read mode (default) – Opens a file for reading; error if file doesn't exist
# - w	Write mode – Creates a new file or overwrites an existing file
# - a	Append mode – Adds content to the end of a file (does not overwrite)
# - x	Exclusive creation – Creates a new file; fails if file already exists
# - t	Text mode (default) – Reads/writes data as text
# - b	Binary mode – Reads/writes data in binary (useful for images, PDFs, etc.)
#
# Example:
#
# "r" → Read
#
# "w" → Write
#
# "rb" → Read in binary
#
# "a+" → Append and read

# %% [markdown]
# ## File Handling Methods
# Python provides various file methods for file handling:
#
#
# - read(size):	Reads size characters (or entire file if not specified)
# - readline():	Reads one line at a time
# - readlines():	Reads all lines and returns a list
# - write(string):	Writes a string to a file
# - writelines(list):	Writes a list of strings to a file
# - open(): Opens the file
# - close():	Closes the file
# - seek(offset):	Moves cursor to a specific position in the file
# - tell():	Returns the current cursor position

# %% [markdown]
# ###  write method

# %%
# Lets open a file for writing:

# style1: write multiple strings
file = open("example.txt", "w")  # Opens in write mode (overwrites file)

msg = "1 Hello, World!\n"
file.write(msg) 

msg = "Life is great\n"
file.write(msg) # Warning: "w" mode will erase existing content before writing new data.

msg = "But homework is torture\n"
file.write(msg) # Warning: "w" mode will erase existing content before writing new data.

file.close()

# view the file in  notepad

# %%
# style2: write multiple strings using a for loop

messages = ["2 Hello, World!\n",
            "Life is great\n",
            "But homework is torture\n"
]

file = open("example.txt", "w")  # Opens in write mode (overwrites file)

for msg in messages:
    file.write(msg) 

file.close()

# view the file in  notepad

# %%
# style3: write multiple strings
msg = """3 Hello, World!
Python is great
But homework is torture
"""

file = open("example.txt", "w")  # Opens in write mode (overwrites file)

file.write(msg) 

file.close()

# view the file in  notepad

# %%
# style4: Using with statement (Recommended)
# Lets redo above using with

msg = """4 Hello, World!
Python is great
But homework is torture
"""

# Open the file in write mode
with open("example.txt", "w") as file:
    file.write(msg)

# The file is automatically closed when using 'with' statement

# %% [markdown]
# ### read method

# %%
# Now lets read the file:

# style1:
# Example: Open a File, store content into a variable, print the variable and then Close It
file = open("example.txt", "r")

content = file.read()
# content = file.read(10) # Reads the first 10 characters

print(content)

file.close()
# Out:
# 4 Hello, World!
# Python is great
# But homework is torture

# %%
# style2: Read All Lines into a List and print the entire list

#step1
file = open("example.txt", "r")

lines = file.readlines()  # Reads all lines into a list
print(lines)

file.close()

print("########################")
# step2: Read All Lines as a List and print in a readable form
for line in lines:
    print(line, end='')

file.close()
# Out:
# ['3 Hello, World!\n', 'Python is great\n', 'But homework is torture\n']
# ########################
# 3 Hello, World!
# Python is great
# But homework is torture

# %%
# style3: read using with statement. 
# with statement closes the file automatically

# Open the file in read mode
with open("example.txt", "r") as file:
    content = file.read()

print(content)
# The file is automatically closed when using 'with' statement
# Out:
# 4 Hello, World!
# Python is great
# But homework is torture

# %%
# a simple application: read text file and print only rows that contains string shamlodhiya and send email to him
# Open the file in read mode

#STEP1: create a simple program
with open("data_people.txt", "r") as file:
    for line in file:
        if "shamlodhiya" in line: 
            print(line)
            print(f"sending email to shamlodhiya")
            print("**********************")


print("################")
# step2: take into account uppercase and lowercase. 
# Also remove extra spaces or newline characters before printing.
with open("data_people.txt", "r") as file:
    for line in file:
        if "shamlodhiya" in line.lower(): 
            print(line.strip())
            print(f"sending email to shamlodhiya")
            print("*****************************")
# Out:
# 209,shamlodhiya,Citeaux,Caravy,France
#
# 328,shamlodhiya,Brown,William,USA
#
# ################
# 209,shamlodhiya,Citeaux,Caravy,France
# 328,shamlodhiya,Brown,William,USA
# 350,Marseille Mini Shamlodhiya,Lebihan,Laurence ,France

# %% [markdown]
# ### append

# %%
# We can also append to a File (a mode)
file = open("example.txt", "a")  # Opens in append mode

file.write("\nAppending new line!")

file.close()

# Open the file in notepad and verify

# %% [markdown]
# # STOP

# %%
# SKIP: ADVANCED: Working with Binary Files
# Binary mode (b) is useful for images, videos, PDFs, etc.

# Example: Copy an Image
with open("image.jpg", "rb") as source:
    with open("junk.jpg", "wb") as copy:
        copy.write(source.read())

# %%
# SKIP: ADVANCED Example: Using seek() and tell()
with open("example.txt", "r") as file:
    print(file.tell())  # Shows cursor position (0 at start)
    print(file.read(5))  # Reads first 5 characters
    print(file.tell())  # Shows new cursor position
    file.seek(0)  # Moves cursor back to the beginning
    print(file.read(2))  # Reads first 2 chars
# Out:
# 0
# Hello
# 5
# Hello

# %% [markdown]
# ## os module

# %%
import os

# 1. Create a new directory
os.mkdir("new_directory")

# 2
os.chdir("new_directory") # Change the current working directory
print("Current Working Directory:", os.getcwd())

# 3. List files in the current directory
files = os.listdir(".")
print("Files in current directory:", files)

# 6. Rename a file
os.rename("example.txt", "renamed_example.txt")

# 7. Delete a file
os.remove("renamed_example.txt")

# 8. Check if a file exists
if os.path.exists("renamed_example.txt"):
    print("File exists.")
else:
    print("File does not exist.")

# %%
# Get file information
if os.path.exists("example.txt"):
    file_info = os.stat("example.txt")
    print("File Size in Bytes:", file_info.st_size)
    print("Last Modified:", file_info.st_mtime)

# %%
# Remove a directory (must be empty)
os.rmdir("new_directory")

# %%
# Check if a path is a file or directory
path = "example.txt"
if os.path.isfile(path):
    print(f"{path} is a file.")
elif os.path.isdir(path):
    print(f"{path} is a directory.")
else:
    print(f"{path} does not exist.")

# %%
import os 

# Walk through a directory tree
for dirpath, dirnames, filenames in os.walk("."):
    print("Current Directory:", dirpath)
    print("Directories:", dirnames)
    print("Files:", filenames)
# Out:
# Current Directory: .
# Directories: ['.git', '.ipynb_checkpoints', '01_Python_Basics', 'practice_questions', 'project_Library_mgmt_system', 'python_applications', 'tut_turtle']
# Files: ['example.txt', 'image.jpg', 'README.md', 'README_NOTES_FOR_PYTHON.txt', 'sample.bin', 'sample_modified.bin', 'tut_py_0_guess_number.py', 'tut_py_0_why_jupyter.ipynb', 'tut_py_1_crash_course.ipynb', 'tut_py_1_print.ipynb', 'tut_py_2_0_operators.ipynb', 'tut_py_2_type_part1_numeric_str_list_tuple.ipynb', 'tut_py_2_type_part2_conditional_ifelse.ipynb', 'tut_py_2_type_part3_loop_for_range_listcomprehension_while_break_continue.ipynb', 'tut_py_2_type_part4_dict_set.ipynb', 'tut_py_2_type_part5_binary.ipynb', 'tut_py_3_function_0_inbuilt-input-isinstance_etc_userDefined_practice.ipynb', 'tut_py_3_function_1_datetime.ipynb', 'tut_py_3_function_2_lambda_reduce_filter_map_any_all.ipynb', 'tut_py_4_0_module.py', 'tut_py_4_module.py', 'tut_py_4_module_math_utils.py', 'tut_py_5_file_handling.ipynb', 'tut_py_5_pip.ipynb', 'tut_py_6_OOP.ipynb', 'tut_py_6_OOP.jpg', 'tut_py_7_exception_handling.ipynb', 'tut_py_8_regex.ipynb', 'tut_py_8_regex.jpg']
# Current Directory: .\.git
# Directories: ['hooks', 'info', 'logs', 'objects', 'refs']
# Files: ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD']
# Current Directory: .\.git\hooks
# Directories: []
# Files: ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# Current Directory: .\.git\info
# Directories: []
# Files: ['exclude']
# Current Directory: .\.git\logs
# Directories: ['refs']
# Files: ['HEAD']
# Current Directory: .\.git\logs\refs
# Directories: ['heads', 'remotes']
# Files: []
# Current Directory: .\.git\logs\refs\heads
# Directories: []
# Files: ['master']
# Current Directory: .\.git\logs\refs\remotes
# Directories: ['origin']
# Files: []
# Current Directory: .\.git\logs\refs\remotes\origin
# Directories: []
# Files: ['master']
# Current Directory: .\.git\objects
# Directories: ['00', '01', '03', '04', '05', '06', '07', '08', '09', '0b', '0c', '0d', '0f', '10', '15', '17', '18', '19', '1c', '1d', '1e', '1f', '23', '24', '26', '28', '29', '2a', '2c', '2d', '2f', '31', '32', '33', '34', '37', '38', '3a', '3b', '3d', '3e', '3f', '40', '42', '44', '45', '4a', '4b', '4d', '4e', '4f', '50', '51', '52', '54', '55', '56', '57', '58', '59', '5a', '5c', '5d', '5e', '5f', '60', '61', '62', '64', '65', '66', '67', '6a', '6b', '6c', '6d', '6e', '6f', '70', '71', '72', '73', '74', '75', '77', '78', '7a', '7b', '7c', '7d', '7e', '81', '83', '84', '85', '86', '87', '89', '8a', '8d', '8f', '91', '92', '93', '94', '95', '97', '99', '9a', '9b', '9d', '9e', '9f', 'a0', 'a1', 'a3', 'a4', 'a6', 'a7', 'aa', 'ab', 'ad', 'ae', 'b0', 'b1', 'b2', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'ba', 'bc', 'bd', 'c0', 'c3', 'c9', 'ca', 'cb', 'cc', 'cd', 'cf', 'd0', 'd1', 'd2', 'd3', 'd5', 'd6', 'd7', 'd9', 'db', 'dc', 'dd', 'de', 'df', 'e1', 'e2', 'e3', 'e6', 'e7', 'e8', 'ea', 'eb', 'ef', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'fa', 'fb', 'fc', 'fe', 'ff', 'info', 'pack']
# Files: []
# Current Directory: .\.git\objects\00
# Directories: []
# Files: ['0e0d3387b5f368944160bb46f64bf455c29d50', '15f59d900c8b40f0b0a06dcb3d2ced5b152870', '4ea0773c51aa7784e942266b84bbec7a976eca']
# Current Directory: .\.git\objects\01
# Directories: []
# Files: ['12174175fe3d1eaff5b16205e78f1bc7925a1a', '6e673fefc9372bcca166f27da9078822e12095']
# Current Directory: .\.git\objects\03
# Directories: []
# Files: ['6d7b5171af77c913a15bfc1bdd95d17a586f9d', '6fd17148b1d24a40e7e4c68defb6b6ab27ef4a']
# Current Directory: .\.git\objects\04
# Directories: []
# Files: ['520c8a52e4db2e6b35514f2093ae781e5a9be9']
# Current Directory: .\.git\objects\05
# Directories: []
# Files: ['18c11282ff22ef9bf1154a265b7e0c664d513c']
# Current Directory: .\.git\objects\06
# Directories: []
# Files: ['37a088a01e8ddab3bf3fa98dbe804cbde1a0dc']
# Current Directory: .\.git\objects\07
# Directories: []
# Files: ['011c0a97b539d0757f214f4d3a0367aa696fc8', 'a18273c3b7bdc650179818b3df565298678dff']
# Current Directory: .\.git\objects\08
# Directories: []
# Files: ['90871081754a2205d25fe81c72f884327f5b1a', '9276ee1b080a3b723c7359cc0702253289909b']
# Current Directory: .\.git\objects\09
# Directories: []
# Files: ['1a18250a06cd6f34e80cae58459dc7e332e66a', '86c77b86c6f8cc72bfea183fc242e8c131b000']
# Current Directory: .\.git\objects\0b
# Directories: []
# Files: ['36de954cdf06df4ef761796aa353a564fbf037', '5acd30a6fbaa13f4be164ff774f0e2def3058c']
# Current Directory: .\.git\objects\0c
# Directories: []
# Files: ['b57ee84801aaff5874509f8dee0b4cb7e6e318']
# Current Directory: .\.git\objects\0d
# Directories: []
# Files: ['235bf5c1abb0ebc6d658ca96469ca68430bba7']
# Current Directory: .\.git\objects\0f
# Directories: []
# Files: ['2cec910fbe51c06b55cf54ba6ac956f313ac1c', 'fd31a252481d32672941dd0e3b689505f9afd8']
# Current Directory: .\.git\objects\10
# Directories: []
# Files: ['c2be2ebc8f3514f67de61e14209ba781aea527']
# Current Directory: .\.git\objects\15
# Directories: []
# Files: ['0d1db8e3d58b90e6ce98fd5a7849f66d1d33d7', '16520302c7c711282336040c6bc1d465a0f6a2', 'e75d453c65025740846f3658210232af3f3565']
# Current Directory: .\.git\objects\17
# Directories: []
# Files: ['e303e7f774252bb352aefa8d7268ee74a2f8c6']
# Current Directory: .\.git\objects\18
# Directories: []
# Files: ['31a32969ec3a075e360ca587219693132c0f26']
# Current Directory: .\.git\objects\19
# Directories: []
# Files: ['5a14e93dc7bdd1e24ec427b13d5e49ed10bba2', '7f1e9ddd234a6764dd1881f7482ee48fe425d4']
# Current Directory: .\.git\objects\1c
# Directories: []
# Files: ['9012b8787d0793c0f02d88c9b470fd4787bed6']
# Current Directory: .\.git\objects\1d
# Directories: []
# Files: ['cb75c28d12e962c09917c835986d1f0d9bb5f6']
# Current Directory: .\.git\objects\1e
# Directories: []
# Files: ['0ee0478e54d8260f97b198d2d6423baa146fd2']
# Current Directory: .\.git\objects\1f
# Directories: []
# Files: ['0d3a5edcfa255abb44a89fb4f871c9d6100357', '867533d289dba301e9fc721327daa402fbed0d', 'b5c0ec0772de313fd77fbcc84097841ca8451e', 'ee4cc8cb9332322dd046c79d6b5f4327514224']
# Current Directory: .\.git\objects\23
# Directories: []
# Files: ['2fe3f1a0ac72fedbeea10d207826c2dcc1fbb8']
# Current Directory: .\.git\objects\24
# Directories: []
# Files: ['e9ab492060281adcecf3249569c984f94be2ec']
# Current Directory: .\.git\objects\26
# Directories: []
# Files: ['28d8516ad506545f16fa5b2fca0f89eaf06120', '7c59ac5d6d76117577ec7091abcce41b61beec']
# Current Directory: .\.git\objects\28
# Directories: []
# Files: ['92420b331978573f020f8d51adb4fffed19bc5']
# Current Directory: .\.git\objects\29
# Directories: []
# Files: ['280f12401cf48951ec9951c9afd9710982735f', '94a2e57aa490ad752ed44f37d95caa96fb72ff']
# Current Directory: .\.git\objects\2a
# Directories: []
# Files: ['b826386fec4b6601efdcb8d4f9b2579bc44f7e']
# Current Directory: .\.git\objects\2c
# Directories: []
# Files: ['73bbffbca55930efe7cfa6ddeb8f71e1de72fa']
# Current Directory: .\.git\objects\2d
# Directories: []
# Files: ['e5fe8d05f4f81736b3d8a4e87d50cc6cd6bc0a']
# Current Directory: .\.git\objects\2f
# Directories: []
# Files: ['7d184c6dd847410deb29e911e1fb94e30b08cf', '97e1ea40c4307077a0c47e6044438f5174fdfe']
# Current Directory: .\.git\objects\31
# Directories: []
# Files: ['1253e685f7c0b199fd42c80a591809914c5d1c']
# Current Directory: .\.git\objects\32
# Directories: []
# Files: ['ecb9e05f6950ca3dea5bbc92ac6c2b98e140b3']
# Current Directory: .\.git\objects\33
# Directories: []
# Files: ['a01846a9b3ce9e0503b7ff988a77d792b87650']
# Current Directory: .\.git\objects\34
# Directories: []
# Files: ['3ac9b65d1f0d35c0fea902b83a5ab580c64352']
# Current Directory: .\.git\objects\37
# Directories: []
# Files: ['85e176ac0074830e94659fd6401ecc441a744e', 'a0b4336f3282890181ba6df951d9d5b326e771']
# Current Directory: .\.git\objects\38
# Directories: []
# Files: ['35fffb89f3726d410f44264400e2e05cf4b1fc', 'c7b94a70599d4c43575ffcdae256fdc1a0bd16']
# Current Directory: .\.git\objects\3a
# Directories: []
# Files: ['9485893263706dd644428201cc454d85a04ae4', 'c966e4f47f6d88d1c2ab2544d8451966665104']
# Current Directory: .\.git\objects\3b
# Directories: []
# Files: ['ae87db295b51d7a126ca7aa2aff8df456856ca']
# Current Directory: .\.git\objects\3d
# Directories: []
# Files: ['6d51f0ca6f92efd931f268de0a17143efc71b7', '9751728dbf0009e6e5671acd4b74760277dd2e']
# Current Directory: .\.git\objects\3e
# Directories: []
# Files: ['aca0754a65f41e537009e6a3e29c648f13b248', 'fa6aa22b684531cf91b9a2bdd0fcfd22ab427e']
# Current Directory: .\.git\objects\3f
# Directories: []
# Files: ['493a40cedd0c830c5a9eb9e3060acbecf95b8e']
# Current Directory: .\.git\objects\40
# Directories: []
# Files: ['b086d2e6039044d5f5b34984a3d762e99ce981']
# Current Directory: .\.git\objects\42
# Directories: []
# Files: ['dc2eb521af2d1a8ece819290be8247654ac795']
# Current Directory: .\.git\objects\44
# Directories: []
# Files: ['82dee4d684df6a27a4f09239f3e652b11ddae7', 'b5a5b1edb14557bba1075f5a1fa4027736bb76']
# Current Directory: .\.git\objects\45
# Directories: []
# Files: ['f1379d1e2d4aa443c93d63b9fb7ebf1634fcc5']
# Current Directory: .\.git\objects\4a
# Directories: []
# Files: ['565d18ffd6284c809ba8d0dea6ae4a07e7135d']
# Current Directory: .\.git\objects\4b
# Directories: []
# Files: ['825dc642cb6eb9a060e54bf8d69288fbee4904']
# Current Directory: .\.git\objects\4d
# Directories: []
# Files: ['ad7da69edbb9d26e58bfe5f75e37209668a18f']
# Current Directory: .\.git\objects\4e
# Directories: []
# Files: ['380db49ec460601850d192236b89e91590a573', 'f6b485a4768ac96eb9acd259a834d00f985cb8']
# Current Directory: .\.git\objects\4f
# Directories: []
# Files: ['aea74c979e9b880e0d3f173e33c610bfe96b38', 'c244f4054b466dfb5210e4ba95c18b4d58cc34']
# Current Directory: .\.git\objects\50
# Directories: []
# Files: ['6c31a5b7233ebf3e85733fd6902e33821893dc']
# Current Directory: .\.git\objects\51
# Directories: []
# Files: ['27e97026c3382ff611ebd166b42fb106372064']
# Current Directory: .\.git\objects\52
# Directories: []
# Files: ['6dc7ac40a5bb36cb645ec561993407b73292ca', 'a8e3f8249934ff812252590103202d48f6116d']
# Current Directory: .\.git\objects\54
# Directories: []
# Files: ['cf0e35ee887466eac846ad247ff1e367a12931']
# Current Directory: .\.git\objects\55
# Directories: []
# Files: ['03d5d7cdfad84292125954daec5f0b63177c60', '19197f37a9870fedfbf78396c17df2c426eb91']
# Current Directory: .\.git\objects\56
# Directories: []
# Files: ['20de7a593a2dcb8259b953b4441d96aa8b6b00', '2369c5b72570e9cc2952771a84deb38c5da002']
# Current Directory: .\.git\objects\57
# Directories: []
# Files: ['79cf013b4ec77c8c044c544c84d0d8b2cb8b8d', '7b9ab0eba4229737c3be1905e8e61bc89a8c84', 'b7e175938949a9535453a726829920a5fffeb4']
# Current Directory: .\.git\objects\58
# Directories: []
# Files: ['7032906a3d83d854f1f8b2ff3efb690316b925']
# Current Directory: .\.git\objects\59
# Directories: []
# Files: ['5ceaa1ee966a7aed7474de9862e09e314cf5c8']
# Current Directory: .\.git\objects\5a
# Directories: []
# Files: ['d1ad90483e1d1863a1a232fea7d017eeda3cba']
# Current Directory: .\.git\objects\5c
# Directories: []
# Files: ['15a1b52cf290a49fe08b9b7925bf51f63f656f', 'ad579359c6a4ce0f9c4621032473fbce7f90d7', 'b9781cc00bb4aa0e96b3dceb5e34852dc81c60']
# Current Directory: .\.git\objects\5d
# Directories: []
# Files: ['321d23beebe08bbb3f6860eac85488e7dc426a', 'fbeaa24d505793dfa880f1763d1edf65d052bf']
# Current Directory: .\.git\objects\5e
# Directories: []
# Files: ['948ae89966d80b358e86da5467c8a72a0aaa3b']
# Current Directory: .\.git\objects\5f
# Directories: []
# Files: ['113e6f35666d628a7a0a12343097f1627d01e7', '226c997962d4af92ee038b315a8f49ef90ce03', 'a9fb85c0e0d18301f015e1ab0958433aa6dc8c']
# Current Directory: .\.git\objects\60
# Directories: []
# Files: ['57127f78424ec8d378eedc567247c98d95980e', '589fe3ed7452f7002694608f14e8082d0a95c9', 'e88dd0d5f0324e979bb6cf489ad59a59db081a']
# Current Directory: .\.git\objects\61
# Directories: []
# Files: ['b409ec381cf741febe41b5868e905d559df9df']
# Current Directory: .\.git\objects\62
# Directories: []
# Files: ['ff0fc6f0f5dac1bfe49311283f0220bfb87a2d']
# Current Directory: .\.git\objects\64
# Directories: []
# Files: ['ab90e6ba34fc31ab6b4f241f85712702388964']
# Current Directory: .\.git\objects\65
# Directories: []
# Files: ['9602e98ec625b7ad5ebbc72fd7b8e4e22fb218']
# Current Directory: .\.git\objects\66
# Directories: []
# Files: ['71b085b24b100e9111638f99d094affa5ff4f5', '7968bfcd97bbeed915d82d77e60cf5053e1a0e', 'a258177bedc69f5397c30c64fcc9ee9d1d1ca0']
# Current Directory: .\.git\objects\67
# Directories: []
# Files: ['6ca578007427c770049e78d50bd2cd87e6da85']
# Current Directory: .\.git\objects\6a
# Directories: []
# Files: ['84f7eb89769caa472eef9a4c37efdea9f46840']
# Current Directory: .\.git\objects\6b
# Directories: []
# Files: ['16741835f953a3b559348303bb4739b16c7e66', '33ec6ba3bbb4dab16f0d8d21e5a2eca91580e8', 'c32560a028f03af898eb9fed847da87460d7e3']
# Current Directory: .\.git\objects\6c
# Directories: []
# Files: ['d82b3f8f102226e3ad7a0febd890bfdc1cab1a']
# Current Directory: .\.git\objects\6d
# Directories: []
# Files: ['5067ad86b08202cc429abc67de1be073203c1d', 'c232f8694b8aed3b23eb6cede62b06de7fb9a5']
# Current Directory: .\.git\objects\6e
# Directories: []
# Files: ['c07d91abab830b1e311aea3a4c5f9949b2d165']
# Current Directory: .\.git\objects\6f
# Directories: []
# Files: ['e543361e2dd245e51c3f267ccfd111a915848b']
# Current Directory: .\.git\objects\70
# Directories: []
# Files: ['d39db0d22ead317ef15775c35b4a14eef69497', 'e438ee7aa483bcc5b65fa423855da3f6e1df93']
# Current Directory: .\.git\objects\71
# Directories: []
# Files: ['7e7221cd33ee0bceb9415ebfa9107c0e112da3', 'd425afbeb2b968122af8390f1613a141e43cf1']
# Current Directory: .\.git\objects\72
# Directories: []
# Files: ['27869adafcaa49624b045c878a34c7975f0c87']
# Current Directory: .\.git\objects\73
# Directories: []
# Files: ['6bfb8dca0f7f1e5227bbd973b5d7798ec22969']
# Current Directory: .\.git\objects\74
# Directories: []
# Files: ['0f9da5fd422c517ecc8db2caa77e9369325feb', '3d2d179af7d7c51fa0a4ddb2865055792a3e1f', '8cbfba26334f6e5b4b94c60c30b1c271701176']
# Current Directory: .\.git\objects\75
# Directories: []
# Files: ['8a663e6c6ffff3796030f0218e2e6efefab0d3']
# Current Directory: .\.git\objects\77
# Directories: []
# Files: ['030d7d0ea36599eb607cb761eec7fb7f191f8c']
# Current Directory: .\.git\objects\78
# Directories: []
# Files: ['9edd3b1a6b646338568dce7b53551dfa97c1b2']
# Current Directory: .\.git\objects\7a
# Directories: []
# Files: ['4fa8ba69841d331f8b0253207ce2b675a15a39']
# Current Directory: .\.git\objects\7b
# Directories: []
# Files: ['b559599ce1e7373d70d38c21d0bd91b7e6ab3d']
# Current Directory: .\.git\objects\7c
# Directories: []
# Files: ['ba83a3431b7c2da560f173220ab09a5eda2464']
# Current Directory: .\.git\objects\7d
# Directories: []
# Files: ['7c9fa97257f54a389905231c4706f8ba38f9fa', '9c42d6d7d81c29e83473a4043ab4a65f5fd3dc', 'dc6a7e12c7ef2d915932ffc35e79ebd3ec508b']
# Current Directory: .\.git\objects\7e
# Directories: []
# Files: ['6c7a5523d9beb5dbeab21617a59fbef2ca846c', '8748fa58cf25b80a4df3f5048c0d7be0ab1f2a']
# Current Directory: .\.git\objects\81
# Directories: []
# Files: ['2772543ab19a629ebf85cd7be2f77ff263435f', '6319daa0d43dbb295f72e4f9bcedc1b3eb356e', 'cb489bb84b3531511d268fdb5edc7a8083bc81']
# Current Directory: .\.git\objects\83
# Directories: []
# Files: ['39d745d87b484dea03ac9f0f7272d8433923b4']
# Current Directory: .\.git\objects\84
# Directories: []
# Files: ['0da19bfabc9fb7747899df47620eff1ee79b58', '578720dd5333006af7732a64a32c2aa5567084', '6e30acf9d3b13c647854d6d065fa421fb29c81']
# Current Directory: .\.git\objects\85
# Directories: []
# Files: ['ab628665cd0d4b9b74525d6b13dc70a7d9d396']
# Current Directory: .\.git\objects\86
# Directories: []
# Files: ['98caf015d571b1c3e48638787010de173ea628', 'e18b73f5e374bef8b04af639f21a5cfe38a2b2']
# Current Directory: .\.git\objects\87
# Directories: []
# Files: ['9435dea3fa4c4e8821b536a75f1faa6330cd25']
# Current Directory: .\.git\objects\89
# Directories: []
# Files: ['c2cd49448ddcac6559256e261ad4026b204494']
# Current Directory: .\.git\objects\8a
# Directories: []
# Files: ['7fa7b62eadb016307666990d15a3b8944a0cd8']
# Current Directory: .\.git\objects\8d
# Directories: []
# Files: ['e8f435179aaa71e5a0855f678d8339f5485bb0']
# Current Directory: .\.git\objects\8f
# Directories: []
# Files: ['8995ebfb87e4f69d4dbfb2a58d45c52bb8764e']
# Current Directory: .\.git\objects\91
# Directories: []
# Files: ['b1299551bda49ab70b6900997d893598232022']
# Current Directory: .\.git\objects\92
# Directories: []
# Files: ['16e7e3dc711c4a37e47360c6a845b4b45c9974']
# Current Directory: .\.git\objects\93
# Directories: []
# Files: ['c310305a8bab55d1505f8e6390aa6bcaf9dc3f']
# Current Directory: .\.git\objects\94
# Directories: []
# Files: ['4d2af530d8a25fcadbcc2bf921c10ab58599da', '5c568e7afc1be304d643212442ac3ff6f3106a']
# Current Directory: .\.git\objects\95
# Directories: []
# Files: ['309bb4828994c1459bc4b510b20001a64f56a1']
# Current Directory: .\.git\objects\97
# Directories: []
# Files: ['9a7dca87d0dbbea1c38f4459bc4764be8e382d']
# Current Directory: .\.git\objects\99
# Directories: []
# Files: ['be9c96a7aeb6ab2507c4893b2533992a519b62']
# Current Directory: .\.git\objects\9a
# Directories: []
# Files: ['44a2395af1520a5b659b219ca2f4f78d49306c', '5b9aa67b7931bd49393989fa93ecfcd927521b']
# Current Directory: .\.git\objects\9b
# Directories: []
# Files: ['22059d29d6322269b51d0b2df421d3ccede22c', 'a78d0bd17070a65a32c9d178bfc770e65e3574', 'dfa98b7e04fa7ae811d74f32bf03ab803f8537']
# Current Directory: .\.git\objects\9d
# Directories: []
# Files: ['f475f09af5b3c094add28a1be43a7e5c67d402']
# Current Directory: .\.git\objects\9e
# Directories: []
# Files: ['ef173e4ed0857b4ff1586b9618e17a5b7e78d7']
# Current Directory: .\.git\objects\9f
# Directories: []
# Files: ['bdb877a3aeafa775161c68813f854cdbcfd825']
# Current Directory: .\.git\objects\a0
# Directories: []
# Files: ['1539f65e41152d9da673117b57e6792b40b062', '42ac8308c4c11358ad594613d129396f1a3497']
# Current Directory: .\.git\objects\a1
# Directories: []
# Files: ['5d7a4d60e4ea06bbf854a4966e2dc18eafd0a5', 'bc4849a3cbda2caf01446edcac3672f773249f']
# Current Directory: .\.git\objects\a3
# Directories: []
# Files: ['f0e2fbe2f1f457adf1efac769ff24b0946f9ca']
# Current Directory: .\.git\objects\a4
# Directories: []
# Files: ['7ba715d85f471443a645e02992b5a5b1890b9b', '98a527b94add180250d01df4dfd772139563cb']
# Current Directory: .\.git\objects\a6
# Directories: []
# Files: ['f5e434541d03c10cdb76be00c9e169e7d48a9e']
# Current Directory: .\.git\objects\a7
# Directories: []
# Files: ['021afa2a8ed174a5014cfb70f8fa50c02a9294', '0f6016a41795a28e860abfbc6741025ec4f27a', '168d63d568e214e9ba08fa4520411c161be352', '97be4083d469226bfb2550e40cf59bff36dc8c']
# Current Directory: .\.git\objects\aa
# Directories: []
# Files: ['e7db30eedbc2d267e6e3ccdede8bdbc2b4eabd']
# Current Directory: .\.git\objects\ab
# Directories: []
# Files: ['3645a63f9d4dcea23391764240cf7512da959d', 'a5bc09e1c302696e3424b6e273fcf6c85955da', 'c08b992ede7009eb6b80afd7996a7df0fcc20c']
# Current Directory: .\.git\objects\ad
# Directories: []
# Files: ['0e7f3d8e7102ca8879d93a863b9a6dcf993e35', '3c0a7cc325648c2af2fce3ff506901d4c53dba', '55b567533901f37245239e894d14ee8d5c6e46', 'e3b9969b34c5464916a6c926d94521fc24a959']
# Current Directory: .\.git\objects\ae
# Directories: []
# Files: ['84dfb493281705261b9193d14c89c9ae6f8c8d']
# Current Directory: .\.git\objects\b0
# Directories: []
# Files: ['15198848ef2331eba8448a632f9fa53bb6418f', '377d72fd31aafaf0bd6e8f2d2c2a5fd4cb0500']
# Current Directory: .\.git\objects\b1
# Directories: []
# Files: ['01c9c3988ebd6af1e7e4a5e1f94f403b57c727', '486bf630d5e76988cbf5ccccb09503428a02d6']
# Current Directory: .\.git\objects\b2
# Directories: []
# Files: ['f407656db01b2a793c813deef952ea23daff42']
# Current Directory: .\.git\objects\b4
# Directories: []
# Files: ['146d0263d8c2582565899a50bebb80d476aaa6']
# Current Directory: .\.git\objects\b5
# Directories: []
# Files: ['3cc50b5e06dd85365822917348239efa2a281f', '3ec6eeeae4da6e9d4684227cac1b42f116debf']
# Current Directory: .\.git\objects\b6
# Directories: []
# Files: ['8499d3b3b9ca6a53a5d6da33c7a29ed1eec00c']
# Current Directory: .\.git\objects\b7
# Directories: []
# Files: ['4d70743b7154a8ad2c81ecb124e289044ac053']
# Current Directory: .\.git\objects\b8
# Directories: []
# Files: ['eea6a0578540645048a1dfe12e63f3588af377', 'f5b0881d8c66c0b3ae55f13b94e37eb22fb809']
# Current Directory: .\.git\objects\b9
# Directories: []
# Files: ['89c83342e973964d1839b1c347b84d1adf5b91']
# Current Directory: .\.git\objects\ba
# Directories: []
# Files: ['59419f9cc80df26c0f3a1cf659e6aa1c376344', 'a8c4a6ecc34ff01903c6635957c2acbeab1d21', 'a97309bb1912b051a60458ed25d46792ae6d6d']
# Current Directory: .\.git\objects\bc
# Directories: []
# Files: ['0fbd738601dd0b293d799db7fd48cbf47fb310', '85449ea39aecc7a406747c47b770e4d4aefc50', '979859f2a7b4f6adac0c6007d32a1c8071ac78', 'c0afe0e7f2af27f5fe699b9f771871e55c1014', 'c2828f84ee9694b3422ee8ebdbc640db03a4d4']
# Current Directory: .\.git\objects\bd
# Directories: []
# Files: ['3722b080be89c4e7154245a119f0ef14a7b46b', 'c4ba85decf6f545480bb9e0fa2d9cfc1e8adc2', 'f7ed331f138f891237df2f2dea338d2e4624f8']
# Current Directory: .\.git\objects\c0
# Directories: []
# Files: ['1b70193dd922a666cce73546ce228820026ebe']
# Current Directory: .\.git\objects\c3
# Directories: []
# Files: ['8066e2c95f413197294beeb19e075e56c04cda', '98be7ee3785ba0ea6392520b4528072e15cba6', 'b523a2c7e7dc7cb08dc88b3ed0d60f9d7cf274']
# Current Directory: .\.git\objects\c9
# Directories: []
# Files: ['119baf5ea5541413768adf9107f684a11b6048', '852aa8a81c66f914406dc27fc92386f047e0a1']
# Current Directory: .\.git\objects\ca
# Directories: []
# Files: ['1eff4da58d332d8295f3fb9e9d8721d78b63a2', '2220fc70626b043a534780ff248110bb866243', 'e2ec2b34b7d2f9df97687dc4af95bc4232c746', 'e9b2caf5a159e90b14fb44bd6813f3cc9083ae']
# Current Directory: .\.git\objects\cb
# Directories: []
# Files: ['49035c93cc77f65ffd8b68cd9d37497c113798', '5e2e139bdb820db0d0c23a28988f91531aec0a', 'eb2d1b373c49d82fee19916df357d74bce6d8d']
# Current Directory: .\.git\objects\cc
# Directories: []
# Files: ['cb3da3e14c8d412f388f70c9d6f9c84f1a8798']
# Current Directory: .\.git\objects\cd
# Directories: []
# Files: ['ce5ea098514dd876d54040a7ba63bac8739221']
# Current Directory: .\.git\objects\cf
# Directories: []
# Files: ['140c11e7d6bd8c0545102ce6f3acf1705d96a1', '152008d0fd08cbc155adce89de5891302416d6', '84e16c2c659a29176987c11ce29a041b4e2112']
# Current Directory: .\.git\objects\d0
# Directories: []
# Files: ['d1c899cd3aa53febad5773270c77cd02a7012c']
# Current Directory: .\.git\objects\d1
# Directories: []
# Files: ['5a7d4531af660327956e7744fa53f89ebac420', '79332835573e6d4d84b9196f1e3d9ce4b272a8', '9f5fde35a0f3e7e78586df8ddf347ac0562ea7', 'ddef8bd73a5b770a383f37d1983f59e45b0a2e', 'feef785ffac0f4c84ea1083260bf43ca4f36d4']
# Current Directory: .\.git\objects\d2
# Directories: []
# Files: ['0034f5416ad9e1932de4efb1c8642d21b6d6c8', 'c829181b4deb82e20f5a374e46eef0f1ff7e7b']
# Current Directory: .\.git\objects\d3
# Directories: []
# Files: ['b4bb84697f3d488240e8ed43016ad38fec3ce3']
# Current Directory: .\.git\objects\d5
# Directories: []
# Files: ['4f7600fb6a8d75cbc1f4b9165d84af65ac0d8f']
# Current Directory: .\.git\objects\d6
# Directories: []
# Files: ['560cce63faa7058b9648eba5c57ef72bcd8cef']
# Current Directory: .\.git\objects\d7
# Directories: []
# Files: ['2adab1cca69000ce996ac04ac9d3f123540be9', '697f3be6afbbf42c902c95298b99ace612dffa', 'b3f8e704b4e33858a688905e28669326450888']
# Current Directory: .\.git\objects\d9
# Directories: []
# Files: ['c51e0fec38c3e942d55e6d2dd66079b0cd1844']
# Current Directory: .\.git\objects\db
# Directories: []
# Files: ['79eb575f463c2ca206356a6543771ab1cf69de']
# Current Directory: .\.git\objects\dc
# Directories: []
# Files: ['84c1b6116f4f60e9eae55f0e204d9440a2ae15']
# Current Directory: .\.git\objects\dd
# Directories: []
# Files: ['302673b92d35a1c1c2885e5f4475ae8d35d15d', '6b0641bd264c9c7e5b9bd93ef259d8ff9fedbb', 'c87fbdeea3c7bf5486332c9c7cbf8904aa6d1d']
# Current Directory: .\.git\objects\de
# Directories: []
# Files: ['ca2f53df5f32c94d57e15ffe38b913d0fd4f3f']
# Current Directory: .\.git\objects\df
# Directories: []
# Files: ['14dace6572e0801e3c300415e6baf4832266f2', '72b45a75d8bd267c6da8b70bbff1516dbecb74']
# Current Directory: .\.git\objects\e1
# Directories: []
# Files: ['f849004f2f625fb70695da1a9a325b82e29b16']
# Current Directory: .\.git\objects\e2
# Directories: []
# Files: ['75b3c76dc9663759e1154d4173ec0c0dc64599']
# Current Directory: .\.git\objects\e3
# Directories: []
# Files: ['5ff0163186eea9da41f52022fa942991bdc444']
# Current Directory: .\.git\objects\e6
# Directories: []
# Files: ['f5e388e0ed665f857da9441f188c2cd19226a7']
# Current Directory: .\.git\objects\e7
# Directories: []
# Files: ['8c042d21158ffe613c1fd11dc505e91aabd8d3']
# Current Directory: .\.git\objects\e8
# Directories: []
# Files: ['3c29f22a11bdcaa644ae1d6259bfa500d31785']
# Current Directory: .\.git\objects\ea
# Directories: []
# Files: ['4afdb002c9e08bda78ed2f64d96159c87221df']
# Current Directory: .\.git\objects\eb
# Directories: []
# Files: ['914aeac7b8062affed1e51e61e8cc457b68f00']
# Current Directory: .\.git\objects\ef
# Directories: []
# Files: ['4050f4c49392311bb81601a03190fc7b546b6f']
# Current Directory: .\.git\objects\f2
# Directories: []
# Files: ['5b238b33beab60c124f8dbcedd12196abb060e']
# Current Directory: .\.git\objects\f3
# Directories: []
# Files: ['0432860994b0f7b73b7ba2ebbe555d9e9ed3be', 'fd13a5d5fa6e3600e182996a86f69fd5477581']
# Current Directory: .\.git\objects\f4
# Directories: []
# Files: ['fc3933b154020304c8950f69451e9d797cbfa0']
# Current Directory: .\.git\objects\f5
# Directories: []
# Files: ['6d33b67154f3cf8dca7b72cec007973a4b2f8e']
# Current Directory: .\.git\objects\f6
# Directories: []
# Files: ['380161ab09fc4fd72c31932f06fcf1564f8429', 'df20f358b426b0b144907562557342ae622967', 'f3d5cc4c582f4ff1b54f72137564e8773a79c2']
# Current Directory: .\.git\objects\f7
# Directories: []
# Files: ['7c70508a6734e1cf543b49b82364924e83eec4']
# Current Directory: .\.git\objects\f8
# Directories: []
# Files: ['43493b2f98e215d941f8cd1696c87088ad2b1c', '4d45543367b0775f62a83570ea439ab814b73c']
# Current Directory: .\.git\objects\f9
# Directories: []
# Files: ['3b01704586106767d6f1f371d9db45944174bb', 'd0c915911b149d39d666da5298817776115b6e']
# Current Directory: .\.git\objects\fa
# Directories: []
# Files: ['4a483b8c8a45964fbf4a1f0bf5fbe201dc23dc']
# Current Directory: .\.git\objects\fb
# Directories: []
# Files: ['84c65e70f66259d39c533a3f029196259f7d69']
# Current Directory: .\.git\objects\fc
# Directories: []
# Files: ['7480807dfa3286f08dfcc94ee7583edd749536']
# Current Directory: .\.git\objects\fe
# Directories: []
# Files: ['1f032025734067b1aa7466a200de1623815a46', 'a2ed1b66b9fd7a8ecaaa83d40ce70fc27f76a0', 'f9f6a3faa564f0f1b8dbcc088ebbaef66b7cbc']
# Current Directory: .\.git\objects\ff
# Directories: []
# Files: ['124d1c09624aa473f131cdb6543495601b8e8a', '5f188a94ee7522a43e24ef8e258c6e6150c6b4', '6e645e575d5ae0b8c5bfb84a753683ae20582a']
# Current Directory: .\.git\objects\info
# Directories: []
# Files: []
# Current Directory: .\.git\objects\pack
# Directories: []
# Files: []
# Current Directory: .\.git\refs
# Directories: ['heads', 'remotes', 'tags']
# Files: []
# Current Directory: .\.git\refs\heads
# Directories: []
# Files: ['master']
# Current Directory: .\.git\refs\remotes
# Directories: ['origin']
# Files: []
# Current Directory: .\.git\refs\remotes\origin
# Directories: []
# Files: ['master']
# Current Directory: .\.git\refs\tags
# Directories: []
# Files: []
# Current Directory: .\.ipynb_checkpoints
# Directories: []
# Files: ['tut_py_1_crash_course-checkpoint.ipynb', 'tut_py_2_0_operators-checkpoint.ipynb', 'tut_py_2_type_part1_numeric_str_tuple_list-checkpoint.ipynb', 'tut_py_2_type_part2_dict_set-checkpoint.ipynb', 'tut_py_5_file_handling-checkpoint.ipynb', 'tut_py_7_exception_handling-checkpoint.ipynb', 'tut_py_crash_course_1-checkpoint.ipynb']
# Current Directory: .\01_Python_Basics
# Directories: ['.ipynb_checkpoints']
# Files: ['L01_Python_Operators.ipynb', 'L02_Data_Types_Master.ipynb', 'tut_py_2_0_operators.ipynb']
# Current Directory: .\01_Python_Basics\.ipynb_checkpoints
# Directories: []
# Files: ['L01_Python_Operators-checkpoint.ipynb', 'L02_Data_Types_Master-checkpoint.ipynb', 'tut_py_2_0_operators-checkpoint.ipynb']
# Current Directory: .\practice_questions
# Directories: []
# Files: ['MCQ_list.ipynb', 'MCQ_operators.ipynb', 'MCQ_str.ipynb', 'Pract_questions_Functions.ipynb', 'Pract_questions_List_Set_Dict_For_If-Else.ipynb', 'Pract_questions_Set_.ipynb', 'Pract_questions_Strings_List_For_If-Else_While.ipynb', 'TODO_Practise_questions_Lambda.ipynb', 'TODO_Practise_questions_map,_filter_and_reduce_Function.ipynb']
# Current Directory: .\project_Library_mgmt_system
# Directories: []
# Files: ['Python_mini_project_LMS.docx']
# Current Directory: .\python_applications
# Directories: ['tut_py_project1_SimpleTaskManagement']
# Files: ['python_implementation_meanVarianceStdDev_leastSquareRegression.ipynb', 'tut_project_list_dict_enumerate_input_quiz.ipynb']
# Current Directory: .\python_applications\tut_py_project1_SimpleTaskManagement
# Directories: []
# Files: ['main.py', 'README.md', 'storage.py', 'tasks.json', 'task_handler.py', 'utils.py']
# Current Directory: .\tut_turtle
# Directories: ['1_simple', '2_fractals']
# Files: []
# Current Directory: .\tut_turtle\1_simple
# Directories: []
# Files: ['ttl_1_simple1_square1.py', 'ttl_1_simple1_square2_spiral.py', 'ttl_1_simple1_triangle_rightAngle.py', 'ttl_1_simple2_triangle_equilateral.py', 'ttl_1_simple3_hexagon.py', 'ttl_1_simple4_star_polygon.py', 'ttl_1_simple5_overlapping_hexagon.py', 'ttl_1_simple6_circles1.py', 'ttl_1_simple6_circles2_spirograph.py', 'ttl_1_simple8_circle_spiral.py']
# Current Directory: .\tut_turtle\2_fractals
# Directories: []
# Files: ['ttl_fractal1_FIU.py', 'ttl_multiple_turtle.py']
