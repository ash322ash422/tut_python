# %% [markdown]
# # Mini Project: Price Per Unit Calculator (CSV)

# %% [markdown]
# ### Project Objective
#
# Read a CSV file containing: fruit, total_price, qty
#
# Calculate price per unit
#
# ### The content of file:
# ```
# fruit,total_price,qty
# Kiwi,120,6
# Guava,30,3
# Banana,50,3
# Orange,23,4
# Mango,200,5
# ```

# %%
import csv

file_name = "L09-data_fruits.csv"

with open(file_name, "r") as file:
    reader = csv.DictReader(file)

    for row in reader:
        fruit = row["fruit"]
        total_price = float(row["total_price"])
        qty = int(row["qty"])

        price_per_unit = total_price / qty
        print(f"Fruit: {fruit} | Price per unit: {price_per_unit}")
# Out:
# Fruit: Kiwi | Price per unit: 20.0
# Fruit: Guava | Price per unit: 10.0
# Fruit: Banana | Price per unit: 16.666666666666668
# Fruit: Orange | Price per unit: 5.75
# Fruit: Mango | Price per unit: 40.0
