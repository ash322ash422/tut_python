# %% [markdown]
# **Math-oriented, interesting assignment questions** focused on **arithmetic, comparison, and assignment operators in Python**, with a **strict rule: no loops and no if-else statements**.
#
#
# ## Arithmetic Operators ( +, −, *, /, //, %, ** )
#
# ### Square–Cube Identity
#
# Given a number `x`, compute:
#
# \[
# (x + 1)^2 - (x - 1)^2
# \]

# %%
x = 5
result = (x + 1)**2 - (x - 1)**2

# %% [markdown]
# ### 2️. Distance Between Two Numbers
#
# Given two numbers `a` and `b`, compute the **absolute distance** between them **without using `abs()`**.
#
# ---

# %%
a = 7
b = 3
distance = ((a - b)**2) ** 0.5

# %% [markdown]
# ### 3️ Last Two Digits of a Number
#
# Given a number `n`, extract the **last two digits** as a single number.
# Example: `n = 5834 → 34`
#
# ---

# %%
n = 5834
last_two = n % 100

# %% [markdown]
# ### 4️ Area Difference
#
# Given radius `r`, compute:
# [
# \text{Area of square of side } (2r) - \text{Area of circle of radius } r
# ]
# Use `π = 3.14`.
#
# ---

# %%
r = 5
pi = 3.14
area_diff = (2*r)**2 - pi * r**2

# %% [markdown]
# ### 5️ Power Remainder
#
# Compute the remainder when ( x^5 ) is divided by `y`.
#
# ---

# %%
x = 3
y = 4
remainder = (x**5) % y

# %% [markdown]
# ## Comparison Operators ( ==, !=, >, <, >=, <= )
#
# ### 6️ Equality Without If
#
# Given two integers `a` and `b`, create an expression that evaluates to
#
# * `True` if both are **exactly equal**
# * `False` otherwise
#
# ---

# %%
a = 10
b = 10
result = (a == b)

print(result)
# Out:
# True

# %% [markdown]
# ### 7️ Between Two Numbers
#
# Given `x`, `low`, and `high`, write a **single expression** that checks if `x` lies **strictly between** `low` and `high`.
#
# ---

# %%
x = 7
low = 3
high = 10
result = (low < x) and (x < high)

# %% [markdown]
# ### 8️ Divisibility Test
#
# Given integers `n` and `d`, write an expression that returns `True` if `n` is divisible by `d`.
#
# ---

# %%
n = 20
d = 5
result = (n % d) == 0

# %% [markdown]
# ### 9️⃣ Same Last Digit
#
# Given numbers `a` and `b`, check if they have the **same last digit**.
#
# ---

# %% [markdown]
# ### 10 Triangle Validity Check
#
# Given sides `a`, `b`, `c`, write a **boolean expression** that checks whether they can form a triangle
# (using the triangle inequality rule).
#
# ---

# %%
a = 3
b = 4
c = 5
result = (a + b > c) and (a + c > b) and (b + c > a)
