# %% [markdown]
# # Simple Calculator with user input
# Create a simple calculator that takes input 2 numbers from user and performs
# - addition, subtraction, multiplication, division and remainder on these 2 numbers

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
print("Remainder Division:", num1 % num2)
# Out:
# Addition: 12.0
# Subtraction: 2.0
# Multiplication: 35.0
# Division: 1.4
# Remainder Division: 2.0
