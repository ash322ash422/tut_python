# %% [markdown]
# # FUNCTION: inbuilt and user-defined
#
# **why do we need function?**
# - Make your code cleaner, reusable, and easier to manage
#
# ## in built function:
# Examples of in built fn:
# - **print(), input(), int(), float(), len(), range(), type(), list(), tuple(), dict(), etc.**
# -  list of all in-built function: https://docs.python.org/3/library/functions.html

# %% [markdown]
# ## We will look at few of them: **help, sum, min, max, sorted, len, zip, round, map**

# %%
# I want to see the list of all in built functions offered by python: 
# I will use print() and dir() in-built function to see all in-built functions. COOL

print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %% [markdown]
# ### The relevant in-built keywords:
# - True, False, None, etc
#
# ### The relevant in-built functions:
#
# 'abs', 'all', 'any', 'ascii', 'bin', 'bool', 'breakpoint', 'bytearray', 'bytes', 'callable', 'chr', 'classmethod', 'compile', 'complex', 'copyright', 'credits', 'delattr', 'dict', 'dir', 'display', 'divmod', 'enumerate', 'eval', 'exec', 'execfile', 'filter', 'float', 'format', 'frozenset', 'get_ipython', 'getattr', 'globals', 'hasattr', 'hash', 'help', 'hex', 'id', 'input', 'int', 'isinstance', 'issubclass', 'iter', 'len', 'license', 'list', 'locals', 'map', 'max', 'memoryview', 'min', 'next', 'object', 'oct', 'open', 'ord', 'pow', 'print', 'property', 'range', 'repr', 'reversed', 'round', 'runfile', 'set', 'setattr', 'slice', 'sorted', 'staticmethod', 'str', 'sum', 'super', 'tuple', 'type', 'vars', 'zip'

# %% [markdown]
# ##  help()

# %%
# help(): display documentation about functions, methods, keywords, etc.
# It’s like Python’s built-in mini-manual system

# help on functions
# print(help('sum')) 
# print(help('print'))
print(help('min'))
# print(help('max'))
# print(help('sorted'))

# on keyword
# print(help(True)) 
# print(help(int))
# Out:
# Help on built-in function min in module builtins:
#
# min(...)
#     min(iterable, *[, default=obj, key=func]) -> value
#     min(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its smallest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the smallest argument.
#
# None

# %% [markdown]
# ## sum(), min(), max()

# %%
numbers = [3, 7, 5, -1] # list 
# numbers = (3, 7, 5, -1) # tuple

res = sum(numbers)
print("Sum:", res)
# Out:
# Sum: 14

# %%
res = min(numbers)
print("Minimum:", res)
# Out:
# Minimum: -1

# %%
res = max(numbers)
print("Maximum:", res)
# Out:
# Maximum: 7

# %% [markdown]
# # sorted  --> VERY USEFUL

# %%
numbers = [3, 7, 5, -1] # list 
# numbers = (3, 7, 5, -1) # tuple

res = sorted(numbers)
print("Sorted numbers:", res)
# Out:
# Sorted numbers: [-1, 3, 5, 7]

# %%
# 1) Sorting a list of dictionaries

products = [
    {"name": "Laptop", "price": 90000, "quantity": 3},
    {"name": "Headphones", "price": 2000, "quantity": 2},
    {"name": "Smartphone", "price": 50000, "quantity": 7},
    {"name": "Keyboard", "price": 1500, "quantity": 3},
    {"name": "Monitor", "price": 12000, "quantity": 4},
]

# sorted_products = sorted(products, key=lambda p: p["price"], reverse=True) # by price
sorted_products = sorted(products, key=lambda p: p["quantity"], reverse=True) # by quantity

for prod in sorted_products:
    print(prod)
# Out:
# {'name': 'Smartphone', 'price': 50000, 'quantity': 7}
# {'name': 'Monitor', 'price': 12000, 'quantity': 4}
# {'name': 'Laptop', 'price': 90000, 'quantity': 3}
# {'name': 'Keyboard', 'price': 1500, 'quantity': 3}
# {'name': 'Headphones', 'price': 2000, 'quantity': 2}

# %%
# 2) Top 3 products

top_3 = sorted_products[:3]
for prod in top_3:
    print(prod)
# Out:
# {'name': 'Smartphone', 'price': 50000, 'quantity': 7}
# {'name': 'Monitor', 'price': 12000, 'quantity': 4}
# {'name': 'Laptop', 'price': 90000, 'quantity': 3}

# %% [markdown]
# ### len()
# This gives the length of list, string, tuple, set, dictionary,etc

# %%
# Need for len function:
# I want to count the num of elements in containers for data

fruits = [ "Guava", "Kiwi", "Mango", "Kiwi" ] # list
# fruits = ( "Guava", "Kiwi", "Mango", "Kiwi" ) # tuple

print(len(fruits))
# Out:
# 4

# %%
fruits = { "Guava", "Kiwi", "Mango" } # set
print(len(fruits))
# Out:
# 3

# %%
fruits_dict = { "Guava": 2,
                "Kiwi": 4 } # dictionary. Fruits:quantity

print(len(fruits_dict))
# Out:
# 2

# %% [markdown]
# ## round()

# %%
prediction = 3.14759
print(round(prediction, 2))
# Out:
# 3.15

# %% [markdown]
# ## zip() for Feature Pairing

# %%
names = ["A", "B", "C"]
scores = [80, 90, 85]

# print(list(zip(names, scores)))
print(dict(zip(names, scores)))

# for name, score in zip(names, scores):
#     print(name, score)
# Out:
# {'A': 80, 'B': 90, 'C': 85}

# %% [markdown]
# ## map() — Feature Transformation

# %%
data = ["1", "2", "3"]
print(data)

# numbers = map(int, data) # convert all number to int data type
numbers = map(float, data) # convert all number to int data type

print(numbers)
print(list(numbers))
# Out:
# ['1', '2', '3']
# ...
# [1.0, 2.0, 3.0]

# %% [markdown]
# # STOP
