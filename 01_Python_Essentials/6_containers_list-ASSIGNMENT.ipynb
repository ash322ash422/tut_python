# %% [markdown]
# # For following assignments, do NOT use loops. Use indexing

# %% [markdown]
# ## Assignment 1: Basic List Math
#
# Problem:
# Given the list below, calculate the sum of the first three elements.

# %%
numbers = [4, 6, 8, 10, 15]

# %% [markdown]
# ## Assignment 2: Average of Two Numbers
#
# Problem:
# Find the average of the first and last elements of the list.
#
# Hint: (a + b) / 2

# %%
values = [20, 40, 60, 80, 45]

# %% [markdown]
# ## Assignment 3: Price Calculation
#
# Problem:
# A shopping cart contains prices. Calculate the total cost of the first two items.

# %%
prices = [299.99, 499.50, 129.00, 45.99]

# %% [markdown]
# ## Assignment 4: Area Calculation Using List Values
#
# Problem:
# The list contains length and width of a rectangle.
# Calculate the area.
#
# area = length × width

# %%
dimensions = [12, 5]

# %% [markdown]
# ## Assignment 5: Percentage Calculation
#
# Problem:
# A student scored marks in two subjects stored in a list.
# Find the percentage assuming each subject is out of 100.
#
# percentage = (total / 200) × 100

# %%
marks = [78, 92]

# %% [markdown]
# ## Assignment 6: Simple Arithmetic on List Elements
#
# Problem:
# Given the list, calculate:
#
# Sum
#
# Difference
#
# Product
#
# Division

# %%
nums = [10, 5]

# %% [markdown]
# ## Assignment 7: Salary Calculation
#
# Problem:
# A list contains basic salary and bonus.
# Calculate the total salary.

# %%
salary = [25000, 4500]

# %% [markdown]
# ## Assignment 8
#
# Problem:
# Given 7 numbers in a list, calculate:
# first_number + middle_number + last_number

# %%
numbers = [12, 34, 62, 1, 2, 6, 8]
