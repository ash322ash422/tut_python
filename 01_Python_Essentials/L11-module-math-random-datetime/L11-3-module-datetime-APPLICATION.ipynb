# %%
## Importing datetime

import datetime

# %% [markdown]
# ## Mini Example: Age Calculator

# %%
birth_year = int(input("Enter your birth year: "))
current_year = datetime.date.today().year

age = current_year - birth_year
print("Your age is:", age)
# Out:
# Enter your birth year:  2000
# Your age is: 26

# %%
# Take input in YYYY-MM-DD format
birth_date_str = input("Enter your birth date (YYYY-MM-DD): ") # 2000-01-15

birth_date = datetime.datetime.strptime(birth_date_str, "%Y-%m-%d").date()

today = datetime.date.today()

difference = (today - birth_date)
days_lived = difference.days

print("You have lived", days_lived, "days.")
# Out:
# Enter your birth date (YYYY-MM-DD):  2000-01-15
# You have lived 9550 days.

# %%
# following prints good morning/afternoon/evening depending when u run this

hr = datetime.datetime.now().hour

if hr < 12:
    print("Good morning!")
elif hr < 18:
    print("Good afternoon!")
else:
    print("Good evening!")
# Out:
# Good evening!

# %%
# Application: adding a timestamp on log files

now = datetime.datetime.now()
filename = now.strftime("logfile-%Y-%m-%d_%H-%M-%S.txt")

# some data is written to above filename
with open(filename, 'w') as file:
    t = now.strftime("%m/%d/%Y, %H:%M:%S")
    file.write(f"{t}: caught SIGTERM, shutting down ") # Write the message to the file
    
print("Saving to:", filename)
# Out:
# Saving to: logfile-2026-03-09_23-28-14.txt

# %% [markdown]
# ## Summary
#
# `date.today()` → today’s date
#
# `datetime.now()` → current date & time
#
# `.year`, `.month`, `.day` → access parts
#
# `timedelta` → date difference
#
# `strftime()` → date → string
#
# `strptime()` → string → date

# %% [markdown]
# * Mini project (Attendance System)
# * Date-based calculator
# * Quiz questions on `datetime`
