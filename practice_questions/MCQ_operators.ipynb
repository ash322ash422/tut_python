# %% [markdown]
# ### Question 1
# What will be the output of the following code?
# ```python
# x = 10
# print(x in [1, 2, 3, 10])
# ```
# A) True
# B) False
# C) 10
# D) None
#
# **Correct Answer:** A) True
#
# ---
#
# ### Question 2
# What will be the output of the following code?
# ```python
# a = True
# b = False
# print(a and b)
# ```
# A) True
# B) False
# C) 1
# D) 0
#
# **Correct Answer:** B) False
#
# ---
#
# ### Question 3
# What will be the output of the following code?
# ```python
# x = 5
# y = 10
# print(x + y * 2)
# ```
# A) 15
# B) 25
# C) 20
# D) 10
#
# **Correct Answer:** A) 25
#
# ---
#
# ### Question 4
# What will be the output of the following code?
# ```python
# x = 5
# y = 10
# print(x < y or x > 10)
# ```
# A) True
# B) False
# C) 1
# D) 0
#
# **Correct Answer:** A) True
#
# ---
#
# ### Question 5
# What will be the output of the following code?
# ```python
# x = 10
# y = 5
# print(x - y * 2)
# ```
# A) 0
# B) 5
# C) 10
# D) 15
#
# **Correct Answer:** A) 0
#
# ---
#
# ### Question 6
# What will be the output of the following code?
# ```python
# x = [1, 2, 3]
# y = [1, 2, 3]
# print(x is y)
# ```
# A) True
# B) False
# C) 1
# D) 0
#
# **Correct Answer:** B) False
#
# ---
#
# ### Question 7
# What will be the output of the following code?
# ```python
# x = 10
# print(not (x > 5))
# ```
# A) True
# B) False
# C) 1
# D) 0
#
# **Correct Answer:** B) False
#
# ---
#
# ### Question 8
# What will be the output of the following code?
# ```python
# x = 5
# y = 10
# print(x + y > 10 and y - x < 5)
# ```
# A) True
# B) False
# C) 1
# D) 0
#
# **Correct Answer:** A) True
#
# ---
#
#
# ### Question 9
# What will be the output of the following code?
# ```python
# x = 0
# y = 5
# print(x or y)
# ```
# A) 0
# B) 5
# C) True
# D) False
#
# **Correct Answer:** B) 5
#
# ---
#
# ### Question 10
# What will be the output of the following code?
# ```python
# a = False
# b = True
# c = False
# print(a or b or c)
# ```
# A) False
# B) True
# C) 1
# D) 0
#
# **Correct Answer:** B) True
#
# ---
